# %% [markdown]
# <a href="https://colab.research.google.com/github/DLPY/python2/blob/main/Working_with_APIs_Covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Public API
# Data can retrieved from an API publically or with a key<br> A publically avaliable example is the covid API (https://api.covid19api.com/summary)

# %%
# Request Liabrary can pull a reponse from an API 
import requests
response = requests.get('https://api.covid19api.com/summary').text

# %%
# This response is in JSON 
response
# Out:
# '{"ID":"69e52ecf-6273-4113-9c54-448934522b91","Message":"","Global":{"NewConfirmed":216793,"TotalConfirmed":633405308,"NewDeaths":461,"TotalDeaths":6604037,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z"},"Countries":[{"ID":"63121a50-a653-4dff-b209-d4d434785bc1","Country":"Afghanistan","CountryCode":"AF","Slug":"afghanistan","NewConfirmed":25,"TotalConfirmed":204417,"NewDeaths":0,"TotalDeaths":7829,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"20a62919-0d04-460b-aae7-fe5ce3f08a67","Country":"Albania","CountryCode":"AL","Slug":"albania","NewConfirmed":13,"TotalConfirmed":333138,"NewDeaths":0,"TotalDeaths":3593,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"1ab4da9b-f7f8-4fb9-a172-157c369fe76c","Country":"Algeria","CountryCode":"DZ","Slug":"algeria","NewConfirmed":5,"TotalConfirmed":270929,"NewDeaths":0,"TotalDeaths":6881,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"c433a257-a71a-4b3c-88c3-2e864f39f01b","Country":"Andorra","CountryCode":"AD","Slug":"andorra","NewConfirmed":0,"TotalConfirmed":46664,"NewDeaths":0,"TotalDeaths":155,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"39da991f-106c-4e5c-8330-23a99ae2bd53","Country":"Angola","CountryCode":"AO","Slug":"angola","NewConfirmed":0,"TotalConfirmed":103131,"NewDeaths":0,"TotalDeaths":1917,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"1dba604c-27f1-4a49-bed3-ce43e989aeb9","Country":"Antarctica","CountryCode":"AQ","Slug":"antarctica","NewConfirmed":0,"TotalConfirmed":11,"NewDeaths":0,"TotalDeaths":0,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"14cfe96e-5932-408e-b4f8-9c665045b06f","Country":"Antigua and Barbuda","CountryCode":"AG","Slug":"antigua-and-barbuda","NewConfirmed":0,"TotalConfirmed":9106,"NewDeaths":0,"TotalDeaths":146,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"ffae54a9-d296-49b3-8944-acaed0a9d873","Country":"Argentina","CountryCode":"AR","Slug":"argentina","NewConfirmed":0,"TotalConfirmed":9720232,"NewDeaths":0,"TotalDeaths":130003,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"344930f3-efa6-44c2-b3bf-74584a7323d9","Country":"Armenia","CountryCode":"AM","Slug":"armenia","NewConfirmed":0,"TotalConfirmed":445397,"NewDeaths":0,"TotalDeaths":8709,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"97a9e84b-71c0-4b0a-bef1-e9d5c487e26f","Country":"Australia","CountryCode":"AU","Slug":"australia","NewConfirmed":7114,"TotalConfirmed":10479214,"NewDeaths":0,"TotalDeaths":15873,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"7ab00cb1-1868-4c60-9f76-c00865365f1e","Country":"Austria","CountryCode":"AT","Slug":"austria","NewConfirmed":3823,"TotalConfirmed":5488376,"NewDeaths":8,"TotalDeaths":21090,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"0831d7f7-f3fe-443c-bbc2-9e9c708ab9c1","Country":"Azerbaijan","CountryCode":"AZ","Slug":"azerbaijan","NewConfirmed":52,"TotalConfirmed":823688,"NewDeaths":2,"TotalDeaths":9961,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"475abdbc-7877-4b4e-86da-668ea88f2a82","Country":"Bahamas","CountryCode":"BS","Slug":"bahamas","NewConfirmed":0,"TotalConfirmed":37433,"NewDeaths":0,"TotalDeaths":833,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"e00e4f18-4597-4e94-8e92-412b58b726cf","Country":"Bahrain","CountryCode":"BH","Slug":"bahrain","NewConfirmed":179,"TotalConfirmed":693261,"NewDeaths":0,"TotalDeaths":1531,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-13T08:28:09.211Z","Premium":{}},{"ID":"e6c37667-ba0d-4cd0-8337-744c882cb926","Country":"Bangladesh","CountryCod ...

# %%
# We can use the JSON library to parse this in to a dictionary
import json 
y = json.loads(response)

# %%
# We can confirm this is a dictionary with the type function 
type(y)
# Out:
# dict

# %%
# This is a large dictionary but follows a pattern - We are interested in Country level details
y
# Out:
# {'ID': '69e52ecf-6273-4113-9c54-448934522b91',
#  'Message': '',
#  'Global': {'NewConfirmed': 216793,
#   'TotalConfirmed': 633405308,
#   'NewDeaths': 461,
#   'TotalDeaths': 6604037,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-13T08:28:09.211Z'},
#  'Countries': [{'ID': '63121a50-a653-4dff-b209-d4d434785bc1',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 204417,
#    'NewDeaths': 0,
#    'TotalDeaths': 7829,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '20a62919-0d04-460b-aae7-fe5ce3f08a67',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 333138,
#    'NewDeaths': 0,
#    'TotalDeaths': 3593,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1ab4da9b-f7f8-4fb9-a172-157c369fe76c',
#    'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 270929,
#    'NewDeaths': 0,
#    'TotalDeaths': 6881,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c433a257-a71a-4b3c-88c3-2e864f39f01b',
#    'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 46664,
#    'NewDeaths': 0,
#    'TotalDeaths': 155,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '39da991f-106c-4e5c-8330-23a99ae2bd53',
#    'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 103131,
#    'NewDeaths': 0,
#    'TotalDeaths': 1917,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1dba604c-27f1-4a49-bed3-ce43e989aeb9',
#    'Country': 'Antarctica',
#    'CountryCode': 'AQ',
#    'Slug': 'antarctica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '14cfe96e-5932-408e-b4f8-9c665045b06f',
#    'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9106,
#    'NewDeaths': 0,
#    'TotalDeaths': 146,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'ffae54a9-d296-49b3-8944-acaed0a9d873',
#    'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9720232,
#    'NewDeaths': 0,
#    'TotalDeaths': 130003,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '344930f3-efa6-44c2-b3bf-74584a7323d9',
#    'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 445397,
#    'NewDeaths': 0,
#    'TotalDeaths': 8709,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '97a9e84b-71c0-4b0a-bef1-e9d5c487e26f',
#    'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 7114,
#    'TotalConfirmed': 10479214,
#    'NewDeaths': 0,
#    'TotalDeaths': 15873,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '7ab00cb1-1868-4c60-9f76-c00865365f1e',
#    'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 3823,
#    'TotalConfirmed': 5488376,
#    'NewDeaths': 8,
#    'TotalDeaths': 21090,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '0831d7f7-f3fe-443c-bbc2-9e9c708ab9c1',
#    'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 52,
#    'TotalConfirmed': 823688,
#    'NewDeaths': 2,
#    'TotalDeaths': 9961,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '475abdbc-7877-4b4e-86da-668ea88f2a82',
#    'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 37433,
#    'NewDeaths': 0,
#    'TotalDeaths': 833,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e00e4f18-4597-4e94-8e92-412b58b726cf',
#    'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 179,
#    'TotalConfirmed': 693261,
#    'NewDeaths': 0,
#    'TotalDeaths': 1531,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e6c37667-ba0d-4cd0-8337-744c882cb926',
#    'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 22,
#    'TotalConfirmed': 2036131,
#    'NewDeaths': 0,
#    'TotalDeaths': 29426,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1318a7eb-6a16-496d-9d15-4054b567ea17',
#    'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 103424,
#    'NewDeaths': 0,
#    'TotalDeaths': 560,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '55a13884-c0a7-47ff-a98a-4874cc19caf8',
#    'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 994037,
#    'NewDeaths': 0,
#    'TotalDeaths': 7118,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'bd876dc8-1f98-47e2-8390-90c3f66240d1',
#    'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4622723,
#    'NewDeaths': 0,
#    'TotalDeaths': 32976,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '652b1391-30a8-4f6b-a6da-cbfe07c0b6d6',
#    'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 68972,
#    'NewDeaths': 0,
#    'TotalDeaths': 687,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '3ee6e844-425b-4c1e-bf41-d3ba54ab84d9',
#    'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27912,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b8d36efd-e45d-44bb-b391-6d740b71b578',
#    'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 62430,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '9210907e-77b7-4df8-89b4-e5248c201f6c',
#    'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 59,
#    'TotalConfirmed': 1109822,
#    'NewDeaths': 0,
#    'TotalDeaths': 22243,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e6abd381-8476-4543-b1d4-9e51e5dba6c4',
#    'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 400185,
#    'NewDeaths': 0,
#    'TotalDeaths': 16184,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '81a75dec-202e-49a9-bd8a-81398c0b363b',
#    'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 326344,
#    'NewDeaths': 0,
#    'TotalDeaths': 2790,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e420194f-e157-44fe-9660-c9c8c579a19c',
#    'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 34908198,
#    'NewDeaths': 0,
#    'TotalDeaths': 688656,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '309c340d-8d1f-4c5c-b38f-d4344bf31a45',
#    'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 244599,
#    'NewDeaths': 0,
#    'TotalDeaths': 225,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '73e3a800-b339-4b98-9c4f-326089424c82',
#    'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 131,
#    'TotalConfirmed': 1283495,
#    'NewDeaths': 1,
#    'TotalDeaths': 37953,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '4a88cede-6a72-420f-a619-22541fa55a1f',
#    'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21631,
#    'NewDeaths': 0,
#    'TotalDeaths': 387,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '03eb83cf-1f46-4b3a-9095-108e43fb81b4',
#    'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 50574,
#    'NewDeaths': 0,
#    'TotalDeaths': 38,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'd9377175-0471-4bf7-bab2-75907cdfede9',
#    'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 137996,
#    'NewDeaths': 0,
#    'TotalDeaths': 3056,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '89d2dd6f-124f-4466-a744-ce383ce88a9e',
#    'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 123993,
#    'NewDeaths': 0,
#    'TotalDeaths': 1965,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'dc531468-68d8-46a7-be6b-d6344223aa48',
#    'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 680,
#    'TotalConfirmed': 3787472,
#    'NewDeaths': 9,
#    'TotalDeaths': 42187,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e36f7315-fd18-49be-a9f2-57737c5b054a',
#    'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 26,
#    'TotalConfirmed': 62672,
#    'NewDeaths': 0,
#    'TotalDeaths': 410,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c349390e-e413-4d01-96dc-5af6f2414ac0',
#    'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15289,
#    'NewDeaths': 0,
#    'TotalDeaths': 113,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1678eaa9-e7d6-45a8-ae65-cbd2a07ac160',
#    'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7631,
#    'NewDeaths': 0,
#    'TotalDeaths': 194,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f91ab9c0-a9ac-4dae-8a55-7a66ca7af3ee',
#    'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 6604,
#    'TotalConfirmed': 4832838,
#    'NewDeaths': 30,
#    'TotalDeaths': 61983,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e6a92525-0a8b-4681-8352-67933b1216f1',
#    'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 7397,
#    'TotalConfirmed': 2252349,
#    'NewDeaths': 6,
#    'TotalDeaths': 15749,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f573b35b-b70e-442a-a610-05eea483479a',
#    'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6311359,
#    'NewDeaths': 0,
#    'TotalDeaths': 141862,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '53b74fc8-abea-4793-bdbc-08cabbcec60b',
#    'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8879,
#    'NewDeaths': 0,
#    'TotalDeaths': 161,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '100d9513-77c6-4f97-b9d8-b6fe1315dcf9',
#    'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24837,
#    'NewDeaths': 0,
#    'TotalDeaths': 386,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1e9f96d5-e8b9-4762-9121-f9ccd647ec5e',
#    'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 93467,
#    'NewDeaths': 0,
#    'TotalDeaths': 1447,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1a11ff07-7364-473f-b023-1759512b2c8a',
#    'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1140864,
#    'NewDeaths': 0,
#    'TotalDeaths': 9019,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c990c8db-2d93-4c52-8604-a553bf6fb39f',
#    'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 244,
#    'TotalConfirmed': 1249943,
#    'NewDeaths': 3,
#    'TotalDeaths': 17218,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '127ade77-6eee-46fd-a824-88b2b830ed1e',
#    'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 1111317,
#    'NewDeaths': 0,
#    'TotalDeaths': 8530,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '2b70d464-8a49-4812-8534-0ee7134d4119',
#    'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 3625,
#    'TotalConfirmed': 606287,
#    'NewDeaths': 10,
#    'TotalDeaths': 1210,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '2987138a-3f6a-4d4d-afa1-01111f0e5623',
#    'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 525,
#    'TotalConfirmed': 4165131,
#    'NewDeaths': 7,
#    'TotalDeaths': 41710,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '595235ff-21e7-4939-a01f-89a9e2e445d1',
#    'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 87851,
#    'NewDeaths': 0,
#    'TotalDeaths': 829,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1cf132d4-3950-4fc1-affd-854ba3000aae',
#    'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3388326,
#    'NewDeaths': 0,
#    'TotalDeaths': 7483,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e1a5b71e-4b88-4227-9bb8-00f3c8b5e7f9',
#    'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15690,
#    'NewDeaths': 0,
#    'TotalDeaths': 189,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f0d5df39-e8a6-46b6-9f59-de6c7dc7d0a5',
#    'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15760,
#    'NewDeaths': 0,
#    'TotalDeaths': 74,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'aae04910-5e40-4022-b84c-895870d94a84',
#    'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 647717,
#    'NewDeaths': 0,
#    'TotalDeaths': 4384,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '9380ecef-97b3-4a6b-8f7e-142c3399762e',
#    'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1009388,
#    'NewDeaths': 0,
#    'TotalDeaths': 35935,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '5a85cc74-1e0c-44bf-9436-b5c60da5bdae',
#    'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 515645,
#    'NewDeaths': 0,
#    'TotalDeaths': 24798,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '6a32349c-9fc6-41f6-b1ed-95a3636a534f',
#    'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 201785,
#    'NewDeaths': 0,
#    'TotalDeaths': 4230,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '5dbe8772-4948-440e-a7c9-84e3dca2c430',
#    'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17182,
#    'NewDeaths': 0,
#    'TotalDeaths': 183,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e7e542ca-b8c6-4c6e-8be2-b46b073c2355',
#    'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10189,
#    'NewDeaths': 0,
#    'TotalDeaths': 103,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '12daeb2b-40ff-4177-b098-6ab3642665fd',
#    'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 607844,
#    'NewDeaths': 0,
#    'TotalDeaths': 2757,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '08eb8850-0804-4f36-a5d6-00edbb36aa73',
#    'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 494180,
#    'NewDeaths': 0,
#    'TotalDeaths': 7572,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '818a4843-1e8d-49b4-992c-a7a7dacbb7eb',
#    'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 68287,
#    'NewDeaths': 0,
#    'TotalDeaths': 878,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '5c10c6b1-b801-43fc-bbf0-7c9012b2f338',
#    'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1372651,
#    'NewDeaths': 0,
#    'TotalDeaths': 6913,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '18d2479f-983b-488f-aae8-bbcf51f0b74d',
#    'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 37288432,
#    'NewDeaths': 0,
#    'TotalDeaths': 158711,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'a3dfefc9-505d-4244-b1fb-3c0615232f20',
#    'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 48945,
#    'NewDeaths': 0,
#    'TotalDeaths': 306,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c21b977d-567c-4722-8229-5f49e491efe2',
#    'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12580,
#    'NewDeaths': 0,
#    'TotalDeaths': 372,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'a66334b1-9b8d-45ea-8a81-60f381cc4e02',
#    'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1785138,
#    'NewDeaths': 0,
#    'TotalDeaths': 16912,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '9fd05d3f-a714-486a-a449-51b133aa67cd',
#    'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 36033395,
#    'NewDeaths': 0,
#    'TotalDeaths': 155588,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '683669eb-6cd0-46e5-8e43-b0dbd5d1a517',
#    'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 170894,
#    'NewDeaths': 0,
#    'TotalDeaths': 1460,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '7af78095-a82a-4508-87c9-a0c63c7aee3a',
#    'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5250288,
#    'NewDeaths': 0,
#    'TotalDeaths': 33888,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'cb439a46-01ac-4178-bb38-a9e339cc58a4',
#    'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19613,
#    'NewDeaths': 0,
#    'TotalDeaths': 237,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'd1a77a2e-ec2d-4e8e-b391-89f91e6b380b',
#    'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 445,
#    'TotalConfirmed': 1145216,
#    'NewDeaths': 4,
#    'TotalDeaths': 19920,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'd4b84263-0625-4e27-9897-52edd9ce00cd',
#    'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 38122,
#    'NewDeaths': 0,
#    'TotalDeaths': 458,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'ce77cded-f30b-402b-9d8d-299961cbb266',
#    'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8848,
#    'NewDeaths': 0,
#    'TotalDeaths': 176,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '00496af2-8d95-4908-a2ec-e605a52cfd40',
#    'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 71468,
#    'NewDeaths': 0,
#    'TotalDeaths': 1281,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'd10c47d1-5814-4dde-b51c-6333e7c316de',
#    'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33828,
#    'NewDeaths': 0,
#    'TotalDeaths': 860,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'dd39906d-729a-43d6-a81a-6b1d8a58b600',
#    'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'dd6d548d-5e23-4fe7-97bb-8f544341b079',
#    'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 457406,
#    'NewDeaths': 0,
#    'TotalDeaths': 11041,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '47e22e2c-c194-4b76-a05c-67f7139f7b82',
#    'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2153564,
#    'NewDeaths': 0,
#    'TotalDeaths': 48111,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f87cf794-afcc-459d-b7e6-5988861a74aa',
#    'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 206803,
#    'NewDeaths': 0,
#    'TotalDeaths': 219,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'd31ef5a3-bd50-49ba-a550-8382d41e1ae4',
#    'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 729,
#    'TotalConfirmed': 44666372,
#    'NewDeaths': 3,
#    'TotalDeaths': 530531,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f7026a77-56e0-4bef-bef7-68d6e3af7e9a',
#    'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 6179,
#    'TotalConfirmed': 6556627,
#    'NewDeaths': 33,
#    'TotalDeaths': 159068,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '62269d1d-f85a-463c-a472-dfb280eddb4f',
#    'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 81,
#    'TotalConfirmed': 7558893,
#    'NewDeaths': 1,
#    'TotalDeaths': 144610,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '97dd640a-d72a-41bb-ab78-42355e0cc689',
#    'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2461857,
#    'NewDeaths': 0,
#    'TotalDeaths': 25361,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'ce02c581-8199-4689-bd0d-3cbcac27b869',
#    'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1675723,
#    'NewDeaths': 0,
#    'TotalDeaths': 8100,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '3433df44-cf6f-4923-acd2-3ae12f014a4d',
#    'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 1017,
#    'TotalConfirmed': 4695853,
#    'NewDeaths': 0,
#    'TotalDeaths': 11788,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '660ee3b7-874f-4ed3-882e-fc5aa802d458',
#    'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23823192,
#    'NewDeaths': 0,
#    'TotalDeaths': 179985,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '72eba19a-5e06-4829-82b1-cef0faf4f46a',
#    'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 152306,
#    'NewDeaths': 0,
#    'TotalDeaths': 3350,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '715af2d6-ab31-4015-8b8b-be4a09d6979b',
#    'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 79486,
#    'TotalConfirmed': 23134961,
#    'NewDeaths': 95,
#    'TotalDeaths': 47618,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c180cb33-a1c5-43d1-b4ad-e157d7f88bdc',
#    'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1746997,
#    'NewDeaths': 0,
#    'TotalDeaths': 14122,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e5533ca5-c35a-4116-a4f3-f95321a15ec3',
#    'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1485203,
#    'NewDeaths': 0,
#    'TotalDeaths': 19053,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '17302f3f-fa26-4f1d-9d0c-4829d7406c6b',
#    'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 162,
#    'TotalConfirmed': 340371,
#    'NewDeaths': 0,
#    'TotalDeaths': 5678,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f333dda4-102d-4e19-82d5-1c5d27d8ce58',
#    'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3430,
#    'NewDeaths': 0,
#    'TotalDeaths': 13,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'acfecb14-abd1-49de-ba42-f10f01f11336',
#    'Country': 'Korea (North)',
#    'CountryCode': 'KP',
#    'Slug': 'korea-north',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c772847c-49c5-4af4-98ec-24712a1648df',
#    'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 48465,
#    'TotalConfirmed': 26194229,
#    'NewDeaths': 48,
#    'TotalDeaths': 29665,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'fce8c7a7-f1f1-4609-82f0-157a3c0a0f34',
#    'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 662359,
#    'NewDeaths': 0,
#    'TotalDeaths': 2569,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e12cdde8-d254-4524-993f-31054b9e0556',
#    'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 206464,
#    'NewDeaths': 0,
#    'TotalDeaths': 2991,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '627e4fc2-1b78-41d8-8af6-10623dfe5323',
#    'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 216357,
#    'NewDeaths': 0,
#    'TotalDeaths': 758,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '2104f2a1-55dd-4a9a-919a-cca08dc714de',
#    'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 956780,
#    'NewDeaths': 0,
#    'TotalDeaths': 6076,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '978c116f-a7e7-4d9a-b19a-aa714d9b964e',
#    'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 108,
#    'TotalConfirmed': 1219573,
#    'NewDeaths': 2,
#    'TotalDeaths': 10720,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'a4fa13e2-2f0f-47c6-8de4-7e69ac70ea6c',
#    'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 34490,
#    'NewDeaths': 0,
#    'TotalDeaths': 706,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'fac53357-f4e7-49c9-8e0d-cb9519688537',
#    'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7998,
#    'NewDeaths': 0,
#    'TotalDeaths': 294,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'bce19bbf-bd85-4519-b8ab-5ce7912328a7',
#    'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 507060,
#    'NewDeaths': 0,
#    'TotalDeaths': 6437,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '14539381-09ba-43f4-b3f2-62a75e7843de',
#    'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20750,
#    'NewDeaths': 0,
#    'TotalDeaths': 87,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '9b83295e-0561-4080-a409-bd0b682eeea2',
#    'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 228,
#    'TotalConfirmed': 1271466,
#    'NewDeaths': 0,
#    'TotalDeaths': 9407,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '2e4b0090-685d-4d93-8998-8875eb6b2a2a',
#    'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 303571,
#    'NewDeaths': 0,
#    'TotalDeaths': 1151,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '0e1621a1-28c6-4efd-84a9-28de248d363d',
#    'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 344342,
#    'NewDeaths': 0,
#    'TotalDeaths': 9564,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b3588d79-323a-4744-933f-b96b04cc6c49',
#    'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 66788,
#    'NewDeaths': 0,
#    'TotalDeaths': 1411,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '061f295e-aaee-44a7-8360-21addfa897fa',
#    'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 88073,
#    'NewDeaths': 0,
#    'TotalDeaths': 2685,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '02c4603a-82ef-46b5-ab90-5c2e3abf20f5',
#    'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 2882,
#    'TotalConfirmed': 4946583,
#    'NewDeaths': 9,
#    'TotalDeaths': 36546,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e691d51d-6c11-4ff2-84ba-cba10359f372',
#    'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 185454,
#    'NewDeaths': 0,
#    'TotalDeaths': 309,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b8c3c868-90f6-4089-892b-e7b03615b15e',
#    'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 32745,
#    'NewDeaths': 0,
#    'TotalDeaths': 742,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'e3c84097-d2a4-4732-9941-fd560449715a',
#    'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 24,
#    'TotalConfirmed': 115587,
#    'NewDeaths': 0,
#    'TotalDeaths': 808,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '30692d35-20de-4445-9e2a-7d4c3aa7c862',
#    'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15389,
#    'NewDeaths': 0,
#    'TotalDeaths': 17,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '3d94dd7f-a590-43c7-945a-7206d57e2052',
#    'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 63412,
#    'NewDeaths': 0,
#    'TotalDeaths': 997,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '5cf3387b-0308-4e92-9f0c-298c04c9ce71',
#    'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 268397,
#    'NewDeaths': 0,
#    'TotalDeaths': 1033,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '44918346-89c7-4e9d-94a8-0e2c22640400',
#    'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7116424,
#    'NewDeaths': 0,
#    'TotalDeaths': 330430,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'd6f00ee2-c78a-4c53-9518-faac163151df',
#    'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22203,
#    'NewDeaths': 0,
#    'TotalDeaths': 58,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '48880af0-091b-497e-93a6-255f3b98da87',
#    'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 594163,
#    'NewDeaths': 0,
#    'TotalDeaths': 11900,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'a65df3d3-4c2a-4002-9dfb-2afd802475c3',
#    'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15071,
#    'NewDeaths': 0,
#    'TotalDeaths': 65,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '52d3228b-e795-4036-984e-3bc0029da835',
#    'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 986599,
#    'NewDeaths': 0,
#    'TotalDeaths': 2131,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '79b62bf9-4052-4184-8409-b6d418a2eb90',
#    'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 32,
#    'TotalConfirmed': 283300,
#    'NewDeaths': 0,
#    'TotalDeaths': 2788,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'd54280e6-5032-4d1b-a28b-49738fdf2f70',
#    'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 103,
#    'TotalConfirmed': 1266561,
#    'NewDeaths': 0,
#    'TotalDeaths': 16283,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c4e415b8-4909-40e3-8cd4-70920bf65b58',
#    'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 230475,
#    'NewDeaths': 0,
#    'TotalDeaths': 2224,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c3f68ea1-15d0-427c-86d1-915fb92786eb',
#    'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 632635,
#    'NewDeaths': 0,
#    'TotalDeaths': 19486,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '7d18d3c4-f7b0-48e1-ad59-f9b6a9e01e7b',
#    'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 169946,
#    'NewDeaths': 0,
#    'TotalDeaths': 4080,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '874ebdfa-3be6-4e91-82cf-3cad3336fff8',
#    'Country': 'Nauru',
#    'CountryCode': 'NR',
#    'Slug': 'nauru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4611,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'a086ebbc-06ce-467c-b451-bee00bdeda29',
#    'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 1000792,
#    'NewDeaths': 0,
#    'TotalDeaths': 12019,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f6a46812-8c86-45a4-becf-9aeb6e433d0b',
#    'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8528384,
#    'NewDeaths': 0,
#    'TotalDeaths': 22871,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f93db55e-d4af-4b2b-81f3-dfc617789b1e',
#    'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1878933,
#    'NewDeaths': 0,
#    'TotalDeaths': 2120,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b665d239-3ffd-4b1d-aab4-41b3edd1be4f',
#    'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15203,
#    'NewDeaths': 0,
#    'TotalDeaths': 245,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c8f23afd-3d00-4531-af68-a2a3718b8a3c',
#    'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9430,
#    'NewDeaths': 0,
#    'TotalDeaths': 314,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'fa0bc2fc-01bb-4e10-8fac-20c4d0afcc06',
#    'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 50,
#    'TotalConfirmed': 266242,
#    'NewDeaths': 0,
#    'TotalDeaths': 3155,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b39d5541-c66d-47a4-a0f5-711ea1b01a6d',
#    'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 57,
#    'TotalConfirmed': 1466523,
#    'NewDeaths': 0,
#    'TotalDeaths': 4286,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b672b21a-f9a9-4a72-b931-62993b69bfa0',
#    'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 398775,
#    'NewDeaths': 0,
#    'TotalDeaths': 4628,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'ffcdb73d-d157-40f0-86dd-222357983695',
#    'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 89,
#    'TotalConfirmed': 1574638,
#    'NewDeaths': 0,
#    'TotalDeaths': 30629,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '9536da93-2875-4401-9fc4-73aa3873e855',
#    'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5530,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'fed461e9-3fd2-4000-b6a8-f800b94314e7',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 703036,
#    'NewDeaths': 0,
#    'TotalDeaths': 5708,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '520e3185-ea10-4047-bd53-6ee5e3e72201',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 991251,
#    'NewDeaths': 0,
#    'TotalDeaths': 8509,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f6ddc0ff-70b2-48bb-a398-857795a1b037',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 45721,
#    'NewDeaths': 0,
#    'TotalDeaths': 668,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '456afcb9-4f5a-4224-8e8c-38f7c814dccd',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 718049,
#    'NewDeaths': 0,
#    'TotalDeaths': 19608,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'd3ecdd44-39a4-4a52-9bc3-96d5bc79993e',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4169751,
#    'NewDeaths': 0,
#    'TotalDeaths': 217172,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '7b10c241-1887-4a10-8d55-a4fe8371d9ed',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 1135,
#    'TotalConfirmed': 4016401,
#    'NewDeaths': 27,
#    'TotalDeaths': 64382,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'fead4f0d-986c-4504-a90c-e4e3e0fc5f7b',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 73,
#    'TotalConfirmed': 6346228,
#    'NewDeaths': 0,
#    'TotalDeaths': 118210,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b195e20a-b400-4ee7-acbf-6fa70fcf1683',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 2807,
#    'TotalConfirmed': 5531172,
#    'NewDeaths': 20,
#    'TotalDeaths': 25339,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '9ce58dd1-9075-4d15-bda2-4f9288d9ad0c',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 206,
#    'TotalConfirmed': 473440,
#    'NewDeaths': 0,
#    'TotalDeaths': 684,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'cecf17ed-8b91-4242-a583-eee34706d939',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 272194,
#    'NewDeaths': 0,
#    'TotalDeaths': 3202,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'fecd701f-03e8-4156-ab58-31e6d7b782ae',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 241,
#    'TotalConfirmed': 3291589,
#    'NewDeaths': 5,
#    'TotalDeaths': 67236,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '82b2210b-5786-4ecd-8559-e37f18525503',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 5448,
#    'TotalConfirmed': 21189139,
#    'NewDeaths': 61,
#    'TotalDeaths': 383075,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b07f86f2-8907-4299-8ec0-eded17987b35',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 132611,
#    'NewDeaths': 0,
#    'TotalDeaths': 1467,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'ea9e607b-f57e-4f87-bd39-dc6c7c9fa0d3',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6552,
#    'NewDeaths': 0,
#    'TotalDeaths': 46,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '61c34d6c-06dc-4d97-b3b3-510e071c7631',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29676,
#    'NewDeaths': 0,
#    'TotalDeaths': 408,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'eaba6539-b186-4685-bbb8-62b6ae6e249f',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9459,
#    'NewDeaths': 0,
#    'TotalDeaths': 116,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'faf33e04-4a64-484f-ad77-25ad44428f58',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15949,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '2077cc43-5e10-42c4-9acf-86bd8065a602',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21739,
#    'NewDeaths': 0,
#    'TotalDeaths': 119,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '322abdd4-cef6-43b6-95dc-f2c4d3161c29',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6275,
#    'NewDeaths': 0,
#    'TotalDeaths': 77,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1104c2cb-87d0-4ab5-9f43-4f68001d64ab',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 61,
#    'TotalConfirmed': 824438,
#    'NewDeaths': 3,
#    'TotalDeaths': 9432,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '5e3f80f3-e5b4-45ba-bfb6-256e6e2978af',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 88832,
#    'NewDeaths': 0,
#    'TotalDeaths': 1968,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '8dd2afa4-3a4a-40a6-8aad-caf13c016b51',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 452,
#    'TotalConfirmed': 2412750,
#    'NewDeaths': 5,
#    'TotalDeaths': 17308,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f353a078-3e88-4838-8148-af97d02b08fa',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 49380,
#    'NewDeaths': 0,
#    'TotalDeaths': 171,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b1a26472-615e-480e-b279-47540c8170d6',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7758,
#    'NewDeaths': 0,
#    'TotalDeaths': 126,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '25b2e4d3-bc42-4761-b058-b9609d866ac0',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 1940,
#    'TotalConfirmed': 2138598,
#    'NewDeaths': 1,
#    'TotalDeaths': 1694,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '4918656f-a6cb-4519-942c-5f84d91a6bd8',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 229,
#    'TotalConfirmed': 2646740,
#    'NewDeaths': 7,
#    'TotalDeaths': 20670,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '2db09682-9889-444c-ac51-f0beebbea379',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 675,
#    'TotalConfirmed': 1242130,
#    'NewDeaths': 0,
#    'TotalDeaths': 6909,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '91b18f69-2ef4-4694-b142-e3c629970146',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21544,
#    'NewDeaths': 0,
#    'TotalDeaths': 153,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '3b9a734c-eb93-4a5b-a358-b42de140ac27',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27254,
#    'NewDeaths': 0,
#    'TotalDeaths': 1361,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '7c08e0ef-5004-4e82-8074-addb30ed9a32',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 464,
#    'TotalConfirmed': 4033182,
#    'NewDeaths': 0,
#    'TotalDeaths': 102371,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '61559568-32e2-4347-b709-04bdca051614',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18325,
#    'NewDeaths': 0,
#    'TotalDeaths': 138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '688f7ee8-27d0-4f34-b507-f3f505f1875f',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 7723,
#    'TotalConfirmed': 13551539,
#    'NewDeaths': 0,
#    'TotalDeaths': 115422,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '40dede22-0445-44a1-905f-ce702558f619',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 22,
#    'TotalConfirmed': 671406,
#    'NewDeaths': 0,
#    'TotalDeaths': 16784,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '4bf10536-128f-4349-b3e2-f258dee43ff2',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 63561,
#    'NewDeaths': 0,
#    'TotalDeaths': 4980,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '7a589c88-b389-4107-8f75-a027ffeb0e36',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 81228,
#    'NewDeaths': 0,
#    'TotalDeaths': 1392,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '00507308-4fc9-4a09-b63c-cfb90de96572',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 73618,
#    'NewDeaths': 0,
#    'TotalDeaths': 1422,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '6aeba7cf-91fb-485c-b158-5ecf74e44191',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2618688,
#    'NewDeaths': 0,
#    'TotalDeaths': 20857,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '46e4c3c7-2edc-4c57-8ebb-56176fc866c9',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4276848,
#    'NewDeaths': 0,
#    'TotalDeaths': 14097,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b2dbdd8e-4f1c-49a1-a54d-72e01038b7a4',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 57378,
#    'NewDeaths': 0,
#    'TotalDeaths': 3163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'bf4ba559-ee5d-4da6-b981-1984ddeb9ff5',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 19208,
#    'TotalConfirmed': 8015698,
#    'NewDeaths': 60,
#    'TotalDeaths': 13501,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '3b86c1c4-ed56-4bd0-b731-2bb180960f45',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17786,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b3bea1a6-f391-4788-8319-1e529c8dc471',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 40152,
#    'NewDeaths': 0,
#    'TotalDeaths': 845,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'efeab2b5-4862-424a-9fe3-425105481264',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4695207,
#    'NewDeaths': 0,
#    'TotalDeaths': 32995,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b091e727-1162-4c75-9896-253983c9b25c',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23312,
#    'NewDeaths': 0,
#    'TotalDeaths': 138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '608d96d3-0f47-49c1-8d24-90f2232695a8',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 39319,
#    'NewDeaths': 0,
#    'TotalDeaths': 290,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '35bda53a-aab2-4a0b-b6c2-23e37854b0f4',
#    'Country': 'Tonga',
#    'CountryCode': 'TO',
#    'Slug': 'tonga',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16182,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '9480ca43-b804-4729-acf8-5aecebee509a',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 184949,
#    'NewDeaths': 0,
#    'TotalDeaths': 4257,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '01b7008d-4fb6-415c-b19c-5267cdcc0550',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1146702,
#    'NewDeaths': 0,
#    'TotalDeaths': 29263,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '3d2c8509-fef8-41e6-9096-e2bce9ac284d',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16919638,
#    'NewDeaths': 0,
#    'TotalDeaths': 101203,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '8e81c211-cadc-4e8c-b6c1-aa8d5cea8d38',
#    'Country': 'Tuvalu',
#    'CountryCode': 'TV',
#    'Slug': 'tuvalu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 163,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '6a116d77-0f40-4a50-a697-18f27ba51691',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 169473,
#    'NewDeaths': 0,
#    'TotalDeaths': 3630,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '863bc22e-4bba-4638-b051-030fce6317c0',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 66,
#    'TotalConfirmed': 5618081,
#    'NewDeaths': 1,
#    'TotalDeaths': 118075,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1ca5e19a-501d-47f4-9902-e5d32b32a8e1',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 217,
#    'TotalConfirmed': 1040821,
#    'NewDeaths': 0,
#    'TotalDeaths': 2348,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '660cfb7f-9d53-4c26-a05c-888a366b918b',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24179656,
#    'NewDeaths': 0,
#    'TotalDeaths': 211417,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b8184d34-26c6-40fb-b020-669706221ba0',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 4674,
#    'TotalConfirmed': 97995355,
#    'NewDeaths': 0,
#    'TotalDeaths': 1074524,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'b62e2733-4c8b-4aaa-93d7-53fb3ceca14e',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 991219,
#    'NewDeaths': 0,
#    'TotalDeaths': 7526,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'ddb51338-4289-4849-b1e8-ea2e7d93fcfe',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 244878,
#    'NewDeaths': 0,
#    'TotalDeaths': 1637,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '46bba691-7387-467d-8b14-a9da6823cb4d',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11981,
#    'NewDeaths': 0,
#    'TotalDeaths': 14,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'a3ab0442-57bc-43b0-b878-944b23a905eb',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 122,
#    'TotalConfirmed': 546384,
#    'NewDeaths': 0,
#    'TotalDeaths': 5824,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '1b732b8a-0279-4377-abe5-459bb87b4f21',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 277,
#    'TotalConfirmed': 11508447,
#    'NewDeaths': 0,
#    'TotalDeaths': 43166,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': '5695ead6-97f0-4274-95d4-4160970bad4a',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11945,
#    'NewDeaths': 0,
#    'TotalDeaths': 2159,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'c621728c-af38-4b1c-9f43-d6ae1ce98d1f',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 333685,
#    'NewDeaths': 0,
#    'TotalDeaths': 4017,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}},
#   {'ID': 'f5585847-cc95-4cdd-baf6-b3c5de720641',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 257893,
#    'NewDeaths': 0,
#    'TotalDeaths': 5606,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-11-13T08:28:09.211Z',
#    'Premium': {}}],
#  'Date': '2022-11-13T08:28:09.211Z'}

# %%
# We can count the number of countries by using the len function 
len(y['Countries'])
# Out:
# 197

# %%
# The first element with country has a country of Afghanistan
y['Countries'][0]['Country']
# Out:
# 'Afghanistan'

# %%
# We can see how many deaths have taken place 
y['Countries'][0]['NewDeaths']
# Out:
# 0

# %%
# We can use f'strings to format a print statement containing elements
f"{y['Countries'][0]['Country']} has had {y['Countries'][0]['TotalDeaths']} total deaths from COVID 19"
# Out:
# 'Afghanistan has had 7829 total deaths from COVID 19'

# %%
# We can do this a number of countries using range
for i in range(10):
  print(f"{y['Countries'][i]['Country']} has had {y['Countries'][i]['TotalDeaths']} total deaths from COVID 19")
# Out:
# Afghanistan has had 7829 total deaths from COVID 19
# Albania has had 3593 total deaths from COVID 19
# Algeria has had 6881 total deaths from COVID 19
# Andorra has had 155 total deaths from COVID 19
# Angola has had 1917 total deaths from COVID 19
# Antarctica has had 0 total deaths from COVID 19
# Antigua and Barbuda has had 146 total deaths from COVID 19
# Argentina has had 130003 total deaths from COVID 19
# Armenia has had 8709 total deaths from COVID 19
# Australia has had 15873 total deaths from COVID 19

# %%
# This data can all be added to a dataframe
import pandas as pd
df = pd.DataFrame(data=y['Countries'])

# %%
df.head(200)
# Out:
#                                        ID                          Country  \
# 0    63121a50-a653-4dff-b209-d4d434785bc1                      Afghanistan
# 1    20a62919-0d04-460b-aae7-fe5ce3f08a67                          Albania
# 2    1ab4da9b-f7f8-4fb9-a172-157c369fe76c                          Algeria
# 3    c433a257-a71a-4b3c-88c3-2e864f39f01b                          Andorra
# 4    39da991f-106c-4e5c-8330-23a99ae2bd53                           Angola
# ..                                    ...                              ...
# 192  a3ab0442-57bc-43b0-b878-944b23a905eb  Venezuela (Bolivarian Republic)
# 193  1b732b8a-0279-4377-abe5-459bb87b4f21                         Viet Nam
# 194  5695ead6-97f0-4274-95d4-4160970bad4a                            Yemen
# 195  c621728c-af38-4b1c-9f43-d6ae1ce98d1f                           Zambia
# 196  f5585847-cc95-4cdd-baf6-b3c5de720641                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan            25          204417          0
# 1            AL      albania            13          333138          0
# 2            DZ      algeria             5          270929          0
# 3            AD      andorra             0           46664          0
# 4            AO       angola             0          103131          0
# ..          ...          ...           ...             ...        ...
# 192          VE    venezuela           122          546384          0
# 193          VN      vietnam           277        11508447          0
# 194          YE        yemen             0           11945          0
# 195          ZM       zambia             0          333685          0
# 196          ZW     zimbabwe             0          257893          0
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date  \
# 0           7829             0               0  2022-11-13T08:28:09.211Z
# 1           3593             0               0  2022-11-13T08:28:09.211Z
# 2           6881             0               0  2022-11-13T08:28:09.211Z
# 3            155             0               0  2022-11-13T08:28:09.211Z
# 4           1917             0               0  2022-11-13T08:28:09.211Z
# ..           ...           ...             ...                       ...
# 192         5824             0               0  2022-11-13T08:28:09.211Z
# 193        43166             0               0  2022-11-13T08:28:09.211Z
# 194         2159             0               0  2022-11-13T08:28:09.211Z
# 195         4017             0               0  2022-11-13T08:28:09.211Z
# 196         5606             0               0  2022-11-13T08:28:09.211Z
#
#     Premium
# 0        {}
# 1        {}
# 2        {}
# 3        {}
# 4        {}
# ..      ...
# 192      {}
# 193      {}
# 194      {}
# 195      {}
# 196      {}
#
# [197 rows x 12 columns]

# %%
# From the dataframe we can get the index of the country with the maximum deaths and cases 
most_new_cases = df['NewConfirmed'].idxmax()
most_new_deaths = df['NewDeaths'].idxmax()

# %%
# We can display this automatically 
print(f" Good Morning here is your daily covid report.\n The most daily confirmed cases look place in {df['Country'].loc[most_new_cases]} with {df['NewConfirmed'].loc[most_new_cases]} new cases.\n The most deaths occured in {df['Country'].loc[most_new_deaths]} with {df['NewDeaths'].loc[most_new_deaths]} new deaths.")
# Out:
#  Good Morning here is your daily covid report.
#  The most daily confirmed cases look place in Japan with 79486 new cases.
#  The most deaths occured in Japan with 95 new deaths.
